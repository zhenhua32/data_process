# %% [markdown]
# # openai 库内部有重试机制, 有点坑, 不如用 http 库来请求

# %%
import os
import json
import base64
from IPython.display import Image as IPyImage, display
from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
base_url = os.getenv("OPENAI_BASE_URL")
